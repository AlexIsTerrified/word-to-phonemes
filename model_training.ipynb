# %%
import re
import io
import json
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.utils import Sequence
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.layers import Embedding, Input, LSTM, Dense, Bidirectional, Concatenate, Dropout
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
# Out:
# WARNING:tensorflow:From C:\Users\aklaa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.

# %%
words = []
phonics_list = []
dict_file = open('./cmudict-01.7b', 'r')
with dict_file as f:
    phonics = [line.rstrip('\n') for line in f]
    for p in phonics:
        x = p.split(' ')
        words.append(x[0])
        phonics_list.append(' '.join(x[1:]))
data = pd.DataFrame({'Word': words, 'Phonics': phonics_list})

data = data.drop(data[data["Word"].str.find("'") == 0].index)
data
# Out:
#                       Word                                    Phonics
# 0       !EXCLAMATION-POINT   EH2 K S K L AH0 M EY1 SH AH0 N P OY2 N T
# 1             "CLOSE-QUOTE                        K L OW1 Z K W OW1 T
# 2            "DOUBLE-QUOTE                    D AH1 B AH0 L K W OW1 T
# 3            "END-OF-QUOTE                    EH1 N D AH0 V K W OW1 T
# 4               "END-QUOTE                          EH1 N D K W OW1 T
# ...                    ...                                        ...
# 133849              {BRACE                                  B R EY1 S
# 133850         {LEFT-BRACE                        L EH1 F T B R EY1 S
# 133851         {OPEN-BRACE                      OW1 P EH0 N B R EY1 S
# 133852        }CLOSE-BRACE                        K L OW1 Z B R EY1 S
# 133853        }RIGHT-BRACE                          R AY1 T B R EY1 S
#
# [133832 rows x 2 columns]

# %%
ILLEGAL_CHAR_REGEX = "[^A-Z']"

MAX_DICT_WORD_LEN = 20
MIN_DICT_WORD_LEN = 2

df = data

def is_alternate_pho_spelling(word):
    if word[-1] == ')' and word[-3] == '(' and word[-2].isdigit():
        return word[:word.find('(')]
    else:
        return word

def should_skip(word):
    if not word[0].isalpha():  # skip symbols
        return True
    if word[-1] == '.':  # skip abbreviations
        return True
    if re.search(ILLEGAL_CHAR_REGEX, word):
        return True
    if len(word) > MAX_DICT_WORD_LEN:
        return True
    if len(word) < MIN_DICT_WORD_LEN:
        return True
    return False
df["Word"] = df["Word"].map(is_alternate_pho_spelling)
df = df[~df["Word"].apply(lambda x : should_skip(x))]
df = df.iloc[np.random.permutation(len(df))].reset_index(drop=True)
df["Phonics"] = df["Phonics"].str.replace(r'[0-9]', '',regex=True)
df
# Out:
#               Word                 Phonics
# 0       SEQUENCING   S IY K W AH N S IH NG
# 1          REITERA         R IY IH T ER AH
# 2        DIETERICH          D IY T ER IH K
# 3          NOVACEK       N AA V AH CH EH K
# 4        MEDICINAL   M AH D IH S AH N AH L
# ...            ...                     ...
# 132550    KRAVCHUK        K R AA V CH UH K
# 132551     DORRELL             D AO R EY L
# 132552   MOUNTAINS         M AW N T AH N Z
# 132553      TELMEX         T EH L M EH K S
# 132554      ACOSTA          AH K AO S T AH
#
# [132555 rows x 2 columns]

# %%
df['Phonics'] = 'startseq '+df['Phonics']+' endseq'
df
# Out:
#               Word                                 Phonics
# 0       SEQUENCING  startseq  S IY K W AH N S IH NG endseq
# 1          REITERA        startseq  R IY IH T ER AH endseq
# 2        DIETERICH         startseq  D IY T ER IH K endseq
# 3          NOVACEK      startseq  N AA V AH CH EH K endseq
# 4        MEDICINAL  startseq  M AH D IH S AH N AH L endseq
# ...            ...                                     ...
# 132550    KRAVCHUK       startseq  K R AA V CH UH K endseq
# 132551     DORRELL            startseq  D AO R EY L endseq
# 132552   MOUNTAINS        startseq  M AW N T AH N Z endseq
# 132553      TELMEX        startseq  T EH L M EH K S endseq
# 132554      ACOSTA         startseq  AH K AO S T AH endseq
#
# [132555 rows x 2 columns]

# %%
max_len_ip = df['Word'].apply(lambda x: len(x)).max()
max_len_op = df['Phonics'].apply(lambda x: len(x.split())).max()

words = df['Word'].tolist()
phonemes = df['Phonics'].tolist()

# %%
char_tokenizer = Tokenizer(char_level=True,oov_token='OOV')
char_tokenizer.fit_on_texts(words)
char_vocab_size = len(char_tokenizer.word_index) + 1
print("Character Vocab Size: ",char_vocab_size)
ch_vocab = char_vocab_size

phone_tokenizer = Tokenizer(oov_token='OOV')
phone_tokenizer.fit_on_texts(phonemes)
phone_vocab_size = len(phone_tokenizer.word_index) + 1
print("Phoneme Vocab Size: ",phone_vocab_size)
ph_vocab = phone_vocab_size
# Out:
# Character Vocab Size:  29
# Phoneme Vocab Size:  43

# %%
char_tokenizer_json = char_tokenizer.to_json()
with io.open('char_tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(char_tokenizer_json, ensure_ascii=False))

phone_tokenizer_json = phone_tokenizer.to_json()
with io.open('phone_tokenizer.json', 'w', encoding='utf-8') as f:
    f.write(json.dumps(phone_tokenizer_json, ensure_ascii=False))

# %%
ch_sequences = char_tokenizer.texts_to_sequences(words)
ph_sequences = phone_tokenizer.texts_to_sequences(phonemes)

# %%
encoder_inputs = pad_sequences(ch_sequences, maxlen=max_len_ip, padding='post')

decoder_inputs = []
decoder_outputs = []

for ph in ph_sequences:
    decoder_inputs.append(ph[:-1])
    decoder_outputs.append(ph[1:])

decoder_inputs = pad_sequences(decoder_inputs, maxlen=max_len_op, padding='post')
decoder_outputs = pad_sequences(decoder_outputs, maxlen=max_len_op, padding='post')

# %%
n = len(words)
split_index = int(0.99 * n)

X_train = [encoder_inputs[:split_index], decoder_inputs[:split_index]]
y_train = decoder_outputs[:split_index]

X_test = words[split_index:]
y_test = phonemes[split_index:]

# %%
# Encoder
char_input = Input(shape=(None,))
x = Embedding(ch_vocab, 256, mask_zero=True)(char_input)
output_y, state_h, state_c = LSTM(256, return_state=True)(x)

# Decoder
ph_input = Input(shape=(None,))
embedding_layer = Embedding(ph_vocab, 256, mask_zero=True)
x = embedding_layer(ph_input)
decoder_lstm = LSTM(256, return_sequences=True, return_state=True)
output_y, _ , _ = decoder_lstm(x, initial_state=[state_h, state_c])
softmax_dense = Dense(ph_vocab, activation='softmax')
output = softmax_dense(output_y)

model = Model(inputs=[char_input, ph_input],outputs=output)
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam')
model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\aklaa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\aklaa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, None)]               0         []
#
#  input_2 (InputLayer)        [(None, None)]               0         []
#
#  embedding (Embedding)       (None, None, 256)            7424      ['input_1[0][0]']
#
#  embedding_1 (Embedding)     (None, None, 256)            11008     ['input_2[0][0]']
#
#  lstm (LSTM)                 [(None, 256),                525312    ['embedding[0][0]']
#                               (None, 256),
#                               (None, 256)]
#
#  lstm_1 (LSTM)               [(None, None, 256),          525312    ['embedding_1[0][0]',
#                               (None, 256),                           'lstm[0][1]',
#                               (None, 256)]                           'lstm[0][2]']
#
#  dense (Dense)               (None, None, 43)             11051     ['lstm_1[0][0]']
#
# ==================================================================================================
# Total params: 1080107 (4.12 MB)
# Trainable params: 1080107 (4.12 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
model_name = "model.h5"
checkpoint = ModelCheckpoint(model_name,
                            monitor="val_loss",
                            mode="min",
                            save_best_only = True,
                            verbose=1)

earlystopping = EarlyStopping(monitor='val_loss',min_delta = 0, patience = 3, verbose = 1, restore_best_weights=True)

# %%
history = model.fit(X_train,y_train,
                    batch_size=32,
                    epochs=20,
                    validation_split=0.01,
                    validation_batch_size=32,
                    callbacks=[checkpoint,earlystopping])
# Out:
# Epoch 1/20
# WARNING:tensorflow:From C:\Users\aklaa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# 4060/4060 [==============================] - ETA: 0s - loss: 0.7269
# Epoch 1: val_loss improved from inf to 0.36097, saving model to model.h5
# 4060/4060 [==============================] - 1154s 283ms/step - loss: 0.7269 - val_loss: 0.3610
# Epoch 2/20
# C:\Users\aklaa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 4060/4060 [==============================] - ETA: 0s - loss: 0.3020
# Epoch 2: val_loss improved from 0.36097 to 0.28175, saving model to model.h5
# 4060/4060 [==============================] - 1164s 287ms/step - loss: 0.3020 - val_loss: 0.2818
# Epoch 3/20
# 4060/4060 [==============================] - ETA: 0s - loss: 0.2384
# Epoch 3: val_loss improved from 0.28175 to 0.24947, saving model to model.h5
# 4060/4060 [==============================] - 1220s 300ms/step - loss: 0.2384 - val_loss: 0.2495
# Epoch 4/20
# 4060/4060 [==============================] - ETA: 0s - loss: 0.2037
# Epoch 4: val_loss improved from 0.24947 to 0.23816, saving model to model.h5
# 4060/4060 [==============================] - 1385s 341ms/step - loss: 0.2037 - val_loss: 0.2382
# Epoch 5/20
# 4060/4060 [==============================] - ETA: 0s - loss: 0.1796
# Epoch 5: val_loss improved from 0.23816 to 0.22695, saving model to model.h5
# 4060/4060 [==============================] - 1444s 356ms/step - loss: 0.1796 - val_loss: 0.2269
# Epoch 6/20
# 4060/4060 [==============================] - ETA: 0s - loss: 0.1610
# Epoch 6: val_loss improved from 0.22695 to 0.22109, saving model to model.h5
# 4060/4060 [==============================] - 1566s 386ms/step - loss: 0.1610 - val_loss: 0.2211
# Epoch 7/20
# 4060/4060 [==============================] - ETA: 0s - loss: 0.1462
# Epoch 7: val_loss did not improve from 0.22109
# 4060/4060 [==============================] - 1529s 377ms/step - loss: 0.1462 - val_loss: 0.2216
# Epoch 8/20
# 4060/4060 [==============================] - ETA: 0s - loss: 0.1347
# Epoch 8: val_loss did not improve from 0.22109
# 4060/4060 [==============================] - 1521s 375ms/step - loss: 0.1347 - val_loss: 0.2248
# Epoch 9/20
# 4060/4060 [==============================] - ETA: 0s - loss: 0.1248
# Epoch 9: val_loss did not improve from 0.22109
# Restoring model weights from the end of the best epoch: 6.
# 4060/4060 [==============================] - 1489s 367ms/step - loss: 0.1248 - val_loss: 0.2287
# Epoch 9: early stopping

# %%
# tf.keras.models.load_model(model_name)

model.save("phoneme_model.h5")
# Out:
# C:\Users\aklaa\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\keras\src\engine\training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
encoder = Model(char_input, [state_h, state_c])

#Decoder
decoder_input_h = Input(shape=(256,))
decoder_input_c = Input(shape=(256,))
x = embedding_layer(ph_input)
x, decoder_output_h, decoder_output_c = decoder_lstm(x, initial_state=[decoder_input_h, decoder_input_c])
x = softmax_dense(x)
decoder = Model([ph_input] + [decoder_input_h, decoder_input_c], 
                                [x] + [decoder_output_h, decoder_output_c])

# %%
def predict_pronunciation(ch_input):
    input_seq = char_tokenizer.texts_to_sequences([ch_input])

    next_h, next_c = encoder.predict(input_seq)

    curr_token = np.zeros((1,1))
    curr_token[0] = phone_tokenizer.word_index['startseq']

    pred_sentence = ''

    for i in range(max_len_op):
        output, next_h, next_c = decoder.predict([curr_token] + [next_h, next_c],verbose=0)
        next_token = np.argmax(output[0, 0, :])
        next_word = phone_tokenizer.index_word[next_token]
        if next_word == 'endseq':
            break
        else:
            pred_sentence += ' ' + next_word
            curr_token[0] = next_token

    return pred_sentence.replace("startseq","").replace("endseq","")

# %%
def predict_acc(x,y):
    x_len = len(x)
    right = 0
    for i in range(x_len):
        phoneme = predict_pronunciation(x[i])
        print(y[i].replace("startseq","").replace("endseq",""), phoneme.upper())
        if  ''.join(filter(lambda x: not x.isdigit(), y[i].replace("startseq","").replace("endseq","").strip())) == ''.join(filter(lambda x: not x.isdigit(), phoneme.upper().strip())):
            right = right + 1

    print(right/x_len)

print(len(X_test))
predict_acc(X_test,y_test)
# Out:
# 1326
# 1/1 [==============================] - 1s 1s/step
#   K AE L IH F AO R N Y AH N Z   K AE L IH F AO R N IY AH N Z
# 1/1 [==============================] - 1s 1s/step
#   IH G Z AE M   IH G Z AA M
# 1/1 [==============================] - 0s 46ms/step
#   N AE SH AH N AE L IH T IY   N AE SH AH N AE L AH T IY
# 1/1 [==============================] - 0s 44ms/step
#   D EH L AH HH AH N T IY   D EH L AH HH AE N T IY
# 1/1 [==============================] - 0s 44ms/step
#   G R AE N D AO T ER   G R AE D N AO R T ER
# 1/1 [==============================] - 0s 48ms/step
#   OW V ER Z EH L AH S   OW V ER Z IY L AH S
# 1/1 [==============================] - 0s 47ms/step
#   G R EY N JH ER   G R EY N JH ER
# 1/1 [==============================] - 0s 44ms/step
#   R IH CH K R IY K   R IH CH R IY K
# 1/1 [==============================] - 0s 47ms/step
#   R AH S K IH N   R AH S K IH N
# 1/1 [==============================] - 0s 46ms/step
#   JH AH S K OW   JH UW S K OW
# 1/1 [==============================] - 0s 47ms/step
#   M AE S T ER P IY S IH Z   M AE S T ER P IY AH S IH Z
# 1/1 [==============================] - 0s 46ms/step
#   M AA R Z   M AA R Z
# 1/1 [==============================] - 0s 45ms/step
#   S IH G N IH T   S IH N IH T
# 1/1 [==============================] - 0s 47ms/step
#   IH M IH T S   EH M IH T S
# 1/1 [==============================] - 0s 44ms/step
#   EH N T ER T EY N IH NG   EH N ER T EY N IH NG
# 1/1 [==============================] - 0s 47ms/step
#   M AH M B AH L   M AH M B AH L
# 1/1 [==============================] - 0s 48ms/step
#   K IH L ER Z   K IH L ER Z
# 1/1 [==============================] - 0s 45ms/step
#   B AO L S AH M   B AE L S AH M
# 1/1 [==============================] - 0s 48ms/step
#   T W AA NG   T W AE NG
# 1/1 [==============================] - 0s 47ms/step
#   M AA R JH R IY   M AA R JH ER IY
# 1/1 [==============================] - 0s 46ms/step
#   B EH L Z B ER G Z   B EH L T S B ER G Z
# 1/1 [==============================] - 0s 44ms/step
#   M OW P T   M OW P T
# 1/1 [==============================] - 0s 46ms/step
#   AW T G R OW Z   AW T G R OW Z
# 1/1 [==============================] - 0s 45ms/step
#   N UW T ER   N UW T ER
# 1/1 [==============================] - 0s 44ms/step
#   S EY F K AA R D Z   S AE F IY K AA D Z
# 1/1 [==============================] - 0s 45ms/step
#   AA N T OW N IY N IY   AA N T OW N IY N IY
# 1/1 [==============================] - 0s 45ms/step
#   SH AH L T AH N   SH AH L T AH N
# 1/1 [==============================] - 0s 46ms/step
#   B IH L Y AH N TH   B IH L Y AH N TH
# 1/1 [==============================] - 0s 45ms/step
#   AH D IY   AH D IY
# 1/1 [==============================] - 0s 47ms/step
#   F AO R AH N ER Z   F AA R N ER Z
# 1/1 [==============================] - 0s 45ms/step
#   F IH K AO R K AH   F IH K AO R K AH
# 1/1 [==============================] - 0s 46ms/step
#   N EH F T IH G AO R S K   N EH F T IH G ER S
# 1/1 [==============================] - 0s 46ms/step
#   OW P AH L IY N   OW P AA L IY N IY
# 1/1 [==============================] - 0s 47ms/step
#   D AH M AE S K AH S IH Z   D AE M AH S K IH S IH Z
# 1/1 [==============================] - 0s 45ms/step
#   K L IH P IH NG Z   K L IH P IH NG Z
# 1/1 [==============================] - 0s 46ms/step
#   HH EH L AH N D   HH EH L AH N D
# 1/1 [==============================] - 0s 45ms/step
#   AA L B AA N OW   AE L B AA N OW
# 1/1 [==============================] - 0s 45ms/step
#   EH M P AH TH AY Z   EH M P AH TH AY Z
# 1/1 [==============================] - 0s 46ms/step
#   M OW T AH V EY T ER   M OW T AH V EY T ER
# 1/1 [==============================] - 0s 46ms/step
#   P EY N K IH L ER Z   P EY N IH K L ER Z
# 1/1 [==============================] - 0s 45ms/step
#   K W AA Z N IY   K W AA S N IY
# 1/1 [==============================] - 0s 46ms/step
#   P UW G   P Y UW G
# 1/1 [==============================] - 0s 46ms/step
#   B AA L EH S T R IH R IY   B AE L EH S T R IY R IY
# 1/1 [==============================] - 0s 46ms/step
#   S T ER T S   S T ER T S
# 1/1 [==============================] - 0s 47ms/step
#   W IH N D M IH L ER   W IH N D M IH L ER
# 1/1 [==============================] - 0s 48ms/step
#   K EY M B R IH JH P AO R T   K AE M B R IH G D ER F
# 1/1 [==============================] - 0s 59ms/step
#   K W EH N Z ER   K W EH N Z ER
# 1/1 [==============================] - 0s 46ms/step
#   G R AH M AH N D Z   G R AH M AH N D Z
# 1/1 [==============================] - 0s 46ms/step
#   N EY   N EH JH
# 1/1 [==============================] - 0s 45ms/step
#   UW AH L   UW L
# 1/1 [==============================] - 0s 46ms/step
#   N EH R EY T ER   N EH R EY T ER
# 1/1 [==============================] - 0s 46ms/step
#   Z AH M B R AH N   Z AH M B R AH N
# 1/1 [==============================] - 0s 46ms/step
#   N UH R AH M B ER G   N UH R AH M B ER G
# 1/1 [==============================] - 0s 45ms/step
#   M IH K S N ER   M IH K S N ER
# 1/1 [==============================] - 0s 46ms/step
#   B AE N T AH   B AE N T AH
# 1/1 [==============================] - 0s 47ms/step
#   K EH T S AH L Z   K EH T Z AH L Z
# 1/1 [==============================] - 0s 47ms/step
#   S AH N B ER D   S AH N B ER D
# 1/1 [==============================] - 0s 47ms/step
#   R IY P AH B L IH K S   R IY P AH B L IH K S
# 1/1 [==============================] - 0s 46ms/step
#   S K R OW L Z   S K R OW L Z
# 1/1 [==============================] - 0s 47ms/step
#   IY P AE L K OW Z   IH P AE L K OW Z
# 1/1 [==============================] - 0s 46ms/step
#   K OW AO R D AH N EY T ER Z   K OW AO R D AH N EY T ER Z
# 1/1 [==============================] - 0s 48ms/step
#   D EY V   D EY V
# 1/1 [==============================] - 0s 45ms/step
#   R EH P T AY L   R EH P T AY L
# 1/1 [==============================] - 0s 47ms/step
#   AE S AH D Z   AE S IH D Z
# 1/1 [==============================] - 0s 49ms/step
#   D EY T AH K W EH S T S   D AE T AH K W EH S T S
# 1/1 [==============================] - 0s 45ms/step
#   IH N S AH B AO R D AH N EY T   IH N S AH B AO R D AH N EY T
# 1/1 [==============================] - 0s 47ms/step
#   F ER AA R IY OW   F ER AA R IY OW
# 1/1 [==============================] - 0s 44ms/step
#   ZH IH R AA R D OW   JH ER AA R D AA T
# 1/1 [==============================] - 0s 47ms/step
#   M AY K AH L Z   M AY K AH L Z
# 1/1 [==============================] - 0s 49ms/step
#   V IY CH IY N OW   V IH S IY N OW
# 1/1 [==============================] - 0s 47ms/step
#   IH R AE S T AH S   IY R AE S T AH S
# 1/1 [==============================] - 0s 45ms/step
#   AH F EH R Z   AH F EH R Z
# 1/1 [==============================] - 0s 45ms/step
#   K EH G L IY   K EH G L IY
# 1/1 [==============================] - 0s 47ms/step
#   T UW M AH K OW CH ER IY   T UW M AH K AO CH ER IY
# 1/1 [==============================] - 0s 45ms/step
#   L AH N Z   L AH N Z
# 1/1 [==============================] - 0s 46ms/step
#   T AE L AH N Z   T AE L AH N Z
# 1/1 [==============================] - 0s 46ms/step
#   N EY B ER Z   N EY B ER Z
# 1/1 [==============================] - 0s 45ms/step
#   M IH S T EY T IH D   M IH S S T EY T IH D
# 1/1 [==============================] - 0s 45ms/step
#   HH AY R Z   HH AY ER Z
# 1/1 [==============================] - 0s 45ms/step
#   B AO B AH L Z   B AA B AH L Z
# 1/1 [==============================] - 0s 45ms/step
#   K OW AH G Z IH S T   K OW AH K S IH S T
# 1/1 [==============================] - 0s 48ms/step
#   AA R K IH T EH K CH ER AH L IY   AA R K AH T EH K T ER AH L IY
# 1/1 [==============================] - 0s 47ms/step
#   S UW AH S AY D AH L   S UW IH S D AH L
# 1/1 [==============================] - 0s 46ms/step
#   K AA K F IY L D   K AA K F IY L D
# 1/1 [==============================] - 0s 47ms/step
#   M AA R AH D OW N AH Z   M EH R AH D AA N AH Z
# 1/1 [==============================] - 0s 45ms/step
#   AH L AA T S   AE L AH T S
# 1/1 [==============================] - 0s 45ms/step
#   TH IY ER IH S T   TH IY ER IH S T
# 1/1 [==============================] - 0s 48ms/step
#   Y OW D AH L IH NG   Y OW D L IH NG
# 1/1 [==============================] - 0s 46ms/step
#   F Y UW CH ER   F Y UW CH ER
# 1/1 [==============================] - 0s 46ms/step
#   S IY M AH N Z   S IY M AH N Z IH Z
# 1/1 [==============================] - 0s 48ms/step
#   W IH L HH IH L M S AH N   W IH L HH IH L S M AH N
# 1/1 [==============================] - 0s 67ms/step
#   N OW CH EH L AH   N OW CH EH L AH
# 1/1 [==============================] - 0s 50ms/step
#   AH N IY Z IY   AH N IY Z IY
# 1/1 [==============================] - 0s 53ms/step
#   B AE L IH S T ER OW Z   B AE L EH S T ER OW Z
# 1/1 [==============================] - 0s 50ms/step
#   M EH R IH T   M EH R IH T
# 1/1 [==============================] - 0s 47ms/step
#   D AH T ER M AH N   D IH T ER M AH N
# 1/1 [==============================] - 0s 44ms/step
#   HH UW   HH UW
# 1/1 [==============================] - 0s 46ms/step
#   EH L D ER Z   EH L D ER Z
# 1/1 [==============================] - 0s 48ms/step
#   CH IH M N IY   CH IH M N IY
# 1/1 [==============================] - 0s 47ms/step
#   S UW   S UW
# 1/1 [==============================] - 0s 47ms/step
#   P AO R N AA G R AH F ER Z   P AO R N AA G R AH F ER Z
# 1/1 [==============================] - 0s 48ms/step
#   AH N D ER G R OW TH   AH N D ER G R OW TH
# 1/1 [==============================] - 0s 64ms/step
#   G L AE D IY OW L AH S   G L AE D IY AH L AH S
# 1/1 [==============================] - 0s 48ms/step
#   L IY K AA R IY   L IY K AA R IY
# 1/1 [==============================] - 0s 47ms/step
#   K AA R T AH N   K AA R T AH N
# 1/1 [==============================] - 0s 58ms/step
#   K L UW JH   K L UW JH
# 1/1 [==============================] - 0s 58ms/step
#   P EH T S UW L OW   P EH T S OW L OW
# 1/1 [==============================] - 0s 50ms/step
#   G L IH S AH N IH NG   G L IH S AH N IH NG
# 1/1 [==============================] - 0s 52ms/step
#   N UW Z   N UW Z
# 1/1 [==============================] - 0s 46ms/step
#   AE V AH N UW   AE V AH N UW
# 1/1 [==============================] - 0s 54ms/step
#   B IY CH L ER   B IY CH L ER
# 1/1 [==============================] - 0s 114ms/step
#   B EY D AH L   B AH D AA L
# 1/1 [==============================] - 0s 49ms/step
#   IH N D ER AH L   IH N D ER AH L
# 1/1 [==============================] - 0s 58ms/step
#   G R OW S B EH K   G R OW S B EH K
# 1/1 [==============================] - 0s 55ms/step
#   S K AA R B ER OW   S K AA R B ER OW
# 1/1 [==============================] - 0s 54ms/step
#   D IH P AO R T IH NG   D IH P AO R T IH NG
# 1/1 [==============================] - 0s 49ms/step
#   B EY S AH N   B EY S IH N
# 1/1 [==============================] - 0s 55ms/step
#   K OW   K OW
# 1/1 [==============================] - 0s 50ms/step
#   K AA M P R AH M AY Z   K AA M P R AH M AY Z
# 1/1 [==============================] - 0s 50ms/step
#   K ER F Y UW   K ER F Y UW
# 1/1 [==============================] - 0s 48ms/step
#   L IH N EH T   L IH N EH T
# 1/1 [==============================] - 0s 66ms/step
#   K EH R AH T IY N Z   K EH R AH T IY N Z
# 1/1 [==============================] - 0s 55ms/step
#   EH M IH L AY N   EH M AH L AY N
# 1/1 [==============================] - 0s 63ms/step
#   CH UW N IH NG   CH UW N IH NG
# 1/1 [==============================] - 0s 53ms/step
#   K OW D AH F AY Z   K OW D AH F AY Z
# 1/1 [==============================] - 0s 54ms/step
#   M AH N T R IY AO L   M AA N T R IY AH L
# 1/1 [==============================] - 0s 51ms/step
#   V AE L IH D   V AE L AH D
# 1/1 [==============================] - 0s 60ms/step
#   JH AY R EY T   JH AY ER T
# 1/1 [==============================] - 0s 50ms/step
#   B ER K AO   B ER K AA
# 1/1 [==============================] - 0s 57ms/step
#   M AE NG G AH M   M AE NG HH AE M
# 1/1 [==============================] - 0s 63ms/step
#   L EY Z   L EY Z
# 1/1 [==============================] - 0s 61ms/step
#   P UW D AO NG   P Y UW D AO NG
# 1/1 [==============================] - 0s 55ms/step
#   M AY K AA M   M AY K AA M
# 1/1 [==============================] - 0s 51ms/step
#   D IH Z ER SH AH N Z   D IH Z ER SH AH N Z
# 1/1 [==============================] - 0s 52ms/step
#   AO T OW M EY K ER Z   AO T OW M EY K ER Z
# 1/1 [==============================] - 0s 61ms/step
#   T EH K N AH K R AE T   T EH K N AH K R AE T
# 1/1 [==============================] - 0s 50ms/step
#   HH IY D IY   HH EH D IY
# 1/1 [==============================] - 0s 58ms/step
#   B R IY S EH N OW Z   B R IH Z IY N OW Z
# 1/1 [==============================] - 0s 52ms/step
#   N ER L   N ER L
# 1/1 [==============================] - 0s 51ms/step
#   K IY S OW   K IY S OW
# 1/1 [==============================] - 0s 56ms/step
#   S T AO R K   S T AO R K
# 1/1 [==============================] - 0s 55ms/step
#   P AA S T UW L AH   P AA S T UW L AH
# 1/1 [==============================] - 0s 51ms/step
#   W AO R N IH NG L IY   W AO R N IH NG L IY
# 1/1 [==============================] - 0s 56ms/step
#   HH W IH P AH L   W IH P AH L
# 1/1 [==============================] - 0s 51ms/step
#   JH AY AH N T S   JH AY AH N T S
# 1/1 [==============================] - 0s 51ms/step
#   Y AW R EY G W IY   Y AW R G IH
# 1/1 [==============================] - 0s 59ms/step
#   S AY N ER   S AY N ER
# 1/1 [==============================] - 0s 57ms/step
#   AH B AO R SH AH N IH S T S   AH B AO R SH AH N IH S T S
# 1/1 [==============================] - 0s 54ms/step
#   K L AY M Z   K L IH M Z
# 1/1 [==============================] - 0s 51ms/step
#   K EY Z AH N   K EY Z AH N
# 1/1 [==============================] - 0s 62ms/step
#   W IY Z L IY   W IY Z L IY
# 1/1 [==============================] - 0s 62ms/step
#   IH T ER EY T IH V   IH T ER AH T IH V
# 1/1 [==============================] - 0s 60ms/step
#   D IY D Z   D IY D Z
# 1/1 [==============================] - 0s 59ms/step
#   EH R P AO R T   EH R P AO R T
# 1/1 [==============================] - 0s 48ms/step
#   R OW Z AH N B ER G Z   R OW Z AH N B ER G Z
# 1/1 [==============================] - 0s 45ms/step
#   D IH M OW SH AH N Z   D IH M OW SH AH N Z
# 1/1 [==============================] - 0s 44ms/step
#   S AW D ER   S AW D ER
# 1/1 [==============================] - 0s 57ms/step
#   R AA K S B AH R OW   R AA K S B ER OW
# 1/1 [==============================] - 0s 47ms/step
#   B EH R AH N AH T S   B EH R AH N EH T S
# 1/1 [==============================] - 0s 60ms/step
#   M AH CH IH G EH M B AH   M AA CH IH G M IY B AH
# 1/1 [==============================] - 0s 50ms/step
#   D IY S M AH   D EH S M AH
# 1/1 [==============================] - 0s 58ms/step
#   F L EH JH L IH NG   F L EH G L IH NG
# 1/1 [==============================] - 0s 47ms/step
#   L AO N D R IY Z   L AO N D R IY Z
# 1/1 [==============================] - 0s 47ms/step
#   M EH L AH D R AA M AH Z   M EH L AH D R AE M AH S
# 1/1 [==============================] - 0s 51ms/step
#   S AE L IH N JH ER   S EY L IH NG ER
# 1/1 [==============================] - 0s 46ms/step
#   T ER L OW   T ER L AW
# 1/1 [==============================] - 0s 51ms/step
#   W AA CH W ER D   W AE CH W ER D
# 1/1 [==============================] - 0s 58ms/step
#   K AA M P T AH N   K AA M P T AH N
# 1/1 [==============================] - 0s 46ms/step
#   L ER K   L ER CH
# 1/1 [==============================] - 0s 47ms/step
#   R UW T S   R UW T S
# 1/1 [==============================] - 0s 60ms/step
#   D AH K EH T   D UW EH T
# 1/1 [==============================] - 0s 46ms/step
#   T S IY   T AY Z
# 1/1 [==============================] - 0s 47ms/step
#   JH IH P S IY Z   JH IH P S IY Z
# 1/1 [==============================] - 0s 47ms/step
#   S IH L AH W EH T IH D   S IH L AH W EH T IH D
# 1/1 [==============================] - 0s 49ms/step
#   L IH K ER Z   L IH K ER Z
# 1/1 [==============================] - 0s 47ms/step
#   S AO L T S B ER G   S AO L Z B ER G
# 1/1 [==============================] - 0s 46ms/step
#   L IH L IY AH N   L IH L Y AH N
# 1/1 [==============================] - 0s 48ms/step
#   B ER CH ER   B ER CH ER
# 1/1 [==============================] - 0s 45ms/step
#   HH AY L AY T IH D   HH AY L AY T IH D
# 1/1 [==============================] - 0s 48ms/step
#   HH W AY T F AO R D   W AY T F ER D
# 1/1 [==============================] - 0s 45ms/step
#   R AH NG   R AH NG
# 1/1 [==============================] - 0s 48ms/step
#   G R AE N D IH S AH N   G R AE N D IH S AH N
# 1/1 [==============================] - 0s 49ms/step
#   EH M P AH TH IY   EH M P AH TH IY
# 1/1 [==============================] - 0s 46ms/step
#   R IY L IY V ER   R IY L IY V ER
# 1/1 [==============================] - 0s 47ms/step
#   P AA L IH K   P AA L IH K
# 1/1 [==============================] - 0s 53ms/step
#   AH L T R AH N AE SH AH N AH L AH S T S   AH L T R AH N AE N SH AH L IH S T S
# 1/1 [==============================] - 0s 47ms/step
#   IH N T ER F EY S   IH N T ER F EY S
# 1/1 [==============================] - 0s 47ms/step
#   N EH K S T EH L   N EH K S T EH L
# 1/1 [==============================] - 0s 47ms/step
#   M AA R IY   M AA R IY
# 1/1 [==============================] - 0s 47ms/step
#   AY S AH M   AY Z AH M
# 1/1 [==============================] - 0s 47ms/step
#   M AH T AH N   M AH T AH N
# 1/1 [==============================] - 0s 48ms/step
#   S EH M EH N T OW S   S EH M EH N T OW Z
# 1/1 [==============================] - 0s 47ms/step
#   AE D R EH S IH Z   AE D R EH S IH Z
# 1/1 [==============================] - 0s 46ms/step
#   D IY B AE K ER   D IH B AE K ER
# 1/1 [==============================] - 0s 47ms/step
#   G OW L D AH N B ER G   G OW L D AH N B ER G
# 1/1 [==============================] - 0s 45ms/step
#   IY V IH NG ER   EH V IH NG ER
# 1/1 [==============================] - 0s 47ms/step
#   M IH S B AH HH EY V   M IH S B AH HH EY V
# 1/1 [==============================] - 0s 48ms/step
#   Y UH R OW K AA P T ER Z   Y UH R OW K AA P T ER Z
# 1/1 [==============================] - 0s 46ms/step
#   IH N AH V EY T IH NG   IH N AH V EY T IH NG
# 1/1 [==============================] - 0s 47ms/step
#   P AA S AH B IH L AH T IY   P AA S AH B IH L AH T IY
# 1/1 [==============================] - 0s 47ms/step
#   L AE CH IH Z   L AE CH IH Z
# 1/1 [==============================] - 0s 50ms/step
#   M AE N D EY T S   M AE N D EY T S
# 1/1 [==============================] - 0s 48ms/step
#   K AA W AA M OW T OW   K AA W AA M OW T OW
# 1/1 [==============================] - 0s 46ms/step
#   W IH L IH N B AO R G   W IH L AH N B ER G
# 1/1 [==============================] - 0s 47ms/step
#   S IY G   S IY G
# 1/1 [==============================] - 0s 46ms/step
#   P ER AH V IH CH   P ER AA V IH CH
# 1/1 [==============================] - 0s 47ms/step
#   W EH DH ER HH EH D   W EH TH ER HH EH D
# 1/1 [==============================] - 0s 54ms/step
#   F IH Z AH L   F IH Z AH L
# 1/1 [==============================] - 0s 70ms/step
#   M AH DH ER L IH S   M AH DH ER L AH S
# 1/1 [==============================] - 0s 48ms/step
#   D R IY HH AW S   D R IY HH AW S
# 1/1 [==============================] - 0s 46ms/step
#   S IH R IH L OW   S ER IH L OW
# 1/1 [==============================] - 0s 49ms/step
#   R IY T R IY T IH NG   R IY T R EY T IH NG
# 1/1 [==============================] - 0s 47ms/step
#   R AA N CH EH R AH   R AA N CH EH R AH
# 1/1 [==============================] - 0s 48ms/step
#   EY TH N   EY TH IY N
# 1/1 [==============================] - 0s 46ms/step
#   IH M P AA R SH IY AE L IH T IY   IH M P AA R SH IY AE L IH T IY
# 1/1 [==============================] - 0s 49ms/step
#   S AH M ER ER   S AH M ER AW R
# 1/1 [==============================] - 0s 46ms/step
#   S T R AY T   S T R AY T
# 1/1 [==============================] - 0s 46ms/step
#   HH EH N D IY   HH EH N D IY
# 1/1 [==============================] - 0s 48ms/step
#   B IH R N   B IH R N
# 1/1 [==============================] - 0s 49ms/step
#   M AA R S AY Z   M AA R S AY L Z
# 1/1 [==============================] - 0s 47ms/step
#   F UH L CH ER   F AH L CH ER
# 1/1 [==============================] - 0s 48ms/step
#   M EY G AH N Z   M EH G AH N Z
# 1/1 [==============================] - 0s 50ms/step
#   HH OW M Z   HH OW L M Z
# 1/1 [==============================] - 0s 48ms/step
#   G R AE N P AA Z   G R AE N D P AH Z
# 1/1 [==============================] - 0s 48ms/step
#   AO R G AH N AH M   AO R G AH N AH M
# 1/1 [==============================] - 0s 48ms/step
#   B ER T S   B ER T S
# 1/1 [==============================] - 0s 47ms/step
#   F AW B AH L   F AW B AH L
# 1/1 [==============================] - 0s 46ms/step
#   R EY M AH N   R EY M AH N
# 1/1 [==============================] - 0s 47ms/step
#   K Y UW L IH N OW V AH   K UW L IY N OW V AH
# 1/1 [==============================] - 0s 48ms/step
#   K L IY TH ER M Z   K L AY AH DH ER M Z
# 1/1 [==============================] - 0s 45ms/step
#   F R EY   F R EY
# 1/1 [==============================] - 0s 57ms/step
#   S AH P AO R T S   S AH P AO R T S
# 1/1 [==============================] - 0s 47ms/step
#   AA L IY SH AH   AE L IH SH AH
# 1/1 [==============================] - 0s 48ms/step
#   S AA L EH K   S AA L EH K
# 1/1 [==============================] - 0s 46ms/step
#   AH P S W IH NG Z   AH P S W IH NG Z
# 1/1 [==============================] - 0s 48ms/step
#   M EH T R AH P OW L   M EH T R AH P AA L
# 1/1 [==============================] - 0s 48ms/step
#   B AA M B ER G ER   B AW M B ER G ER
# 1/1 [==============================] - 0s 47ms/step
#   K AA N F R AH N S AH Z   K AH N F ER AH N S IH Z
# 1/1 [==============================] - 0s 46ms/step
#   IH K S P R EH S   EH K S P EH R Z
# 1/1 [==============================] - 0s 46ms/step
#   N AE CH OW Z   N AE CH OW Z
# 1/1 [==============================] - 0s 49ms/step
#   F AA S N AO   F AA S N AO
# 1/1 [==============================] - 0s 49ms/step
#   R UH R AH T EY N IY AH   R UW R IY AE N IY AH
# 1/1 [==============================] - 0s 46ms/step
#   F UW CH IY   F UW CH IY
# 1/1 [==============================] - 0s 49ms/step
#   D IY L ER Z   D IY L ER Z
# 1/1 [==============================] - 0s 47ms/step
#   M OW L D IH N HH AW ER   M OW L D AH N AW ER
# 1/1 [==============================] - 0s 46ms/step
#   CH IY T ER   CH IY T ER
# 1/1 [==============================] - 0s 47ms/step
#   B R AW Z IH NG   B R AW Z IH NG
# 1/1 [==============================] - 0s 46ms/step
#   R EH L AH G EY T IH D   R EH L AH G EY T IH D
# 1/1 [==============================] - 0s 45ms/step
#   R UW N AW   R UW N AW
# 1/1 [==============================] - 0s 49ms/step
#   AH N W AA SH T   AH N W AA SH T
# 1/1 [==============================] - 0s 48ms/step
#   R IH P IY T ER Z   R IY P IY T ER Z
# 1/1 [==============================] - 0s 47ms/step
#   IH R AH G EY T ER   IH R AH G EY T ER
# 1/1 [==============================] - 0s 47ms/step
#   HH Y UW L IH T   HH AH G L IH T
# 1/1 [==============================] - 0s 47ms/step
#   K R IH S T AH L   K R IH S T AH L
# 1/1 [==============================] - 0s 47ms/step
#   T UW L W ER K S   T UW L W ER K S
# 1/1 [==============================] - 0s 48ms/step
#   P R IY Z EH N T M AH N T   P R IY Z EH N T M AH N T
# 1/1 [==============================] - 0s 46ms/step
#   M AE S M AH N   M AE S M AH N
# 1/1 [==============================] - 0s 47ms/step
#   B AA R EY N   B AA R EY N
# 1/1 [==============================] - 0s 46ms/step
#   T R IY T IH NG   T R IY T IH NG
# 1/1 [==============================] - 0s 48ms/step
#   S T EH R K EY S   S T EH R K EY S
# 1/1 [==============================] - 0s 49ms/step
#   R EY N K OW T S   R EY N K OW AA T S
# 1/1 [==============================] - 0s 49ms/step
#   B ER D S IY D   B ER D S IY D
# 1/1 [==============================] - 0s 48ms/step
#   SH ER B UH R N   SH ER B ER N
# 1/1 [==============================] - 0s 48ms/step
#   TH OW L   TH OW L
# 1/1 [==============================] - 0s 49ms/step
#   P AA N D ER OW S AH Z   P AA N D ER OW S AH Z
# 1/1 [==============================] - 0s 48ms/step
#   IH N S AH L EY T ER Z   IH N S AH L EY T ER Z
# 1/1 [==============================] - 0s 45ms/step
#   Z IH CH   Z IH CH
# 1/1 [==============================] - 0s 46ms/step
#   K R AH K B ER G   K R AH K B EH R G
# 1/1 [==============================] - 0s 48ms/step
#   AH N W IH T IH NG   AH N W IH T IH NG
# 1/1 [==============================] - 0s 47ms/step
#   S AY D B AA R   S AY D B AA R
# 1/1 [==============================] - 0s 44ms/step
#   M AA R K EH L   M AA R K AH L
# 1/1 [==============================] - 0s 45ms/step
#   N AA N EY T IH V   N AA N AH T IH V
# 1/1 [==============================] - 0s 47ms/step
#   K R EH S AH N   K R EH S AH N
# 1/1 [==============================] - 0s 46ms/step
#   K AH M B ER L EH JH   K AH M B ER L IH JH
# 1/1 [==============================] - 0s 48ms/step
#   AA N D ER D AH NG K   AA N D ER D AA NG K
# 1/1 [==============================] - 0s 48ms/step
#   IH V AE P ER EY T AH D   IH V AE P ER EY T IH D
# 1/1 [==============================] - 0s 49ms/step
#   K AA S IH CH IH Z   K AA Z IH K S
# 1/1 [==============================] - 0s 48ms/step
#   K AH M IY K   K M IY EH K
# 1/1 [==============================] - 0s 49ms/step
#   HH EH N D R IY Z   HH EH N D R IY Z
# 1/1 [==============================] - 0s 49ms/step
#   S AH K S IH NG K T   S AH K IH NG K T
# 1/1 [==============================] - 0s 46ms/step
#   M OW D IY   M OW D IY
# 1/1 [==============================] - 0s 48ms/step
#   M UW R IH NG Z   M AO R IH NG Z
# 1/1 [==============================] - 0s 49ms/step
#   P ER K AH V IH CH   P ER K AH V IH CH
# 1/1 [==============================] - 0s 49ms/step
#   HH AA R B ER Z   HH AA R B ER Z
# 1/1 [==============================] - 0s 46ms/step
#   B AE N IH G AH Z   B AA N IH G AH Z
# 1/1 [==============================] - 0s 47ms/step
#   SH W AO N   SH W AO N
# 1/1 [==============================] - 0s 48ms/step
#   D R EH M T   D R IY M T
# 1/1 [==============================] - 0s 47ms/step
#   N AW AH D EY Z   N AW AH D EY Z
# 1/1 [==============================] - 0s 53ms/step
#   AY T EH K   AY T EH K
# 1/1 [==============================] - 0s 47ms/step
#   AO L S T AH N   AE L S T AH N
# 1/1 [==============================] - 0s 46ms/step
#   S T EH L TH   S T EH L TH
# 1/1 [==============================] - 0s 48ms/step
#   N AA D AE L   N EY D AH L
# 1/1 [==============================] - 0s 53ms/step
#   AH D V AE N S ER   AE D V AE N S ER
# 1/1 [==============================] - 0s 49ms/step
#   R AY N AH S   R AY N AH S
# 1/1 [==============================] - 0s 49ms/step
#   EH M IH L AY N   EH M AH L AY N
# 1/1 [==============================] - 0s 47ms/step
#   R OW D IY N IY   R OW D IY N IY
# 1/1 [==============================] - 0s 45ms/step
#   TH AO T   TH AO T
# 1/1 [==============================] - 0s 48ms/step
#   L IH S T   L IH S T
# 1/1 [==============================] - 0s 45ms/step
#   T AA M L IH N S AH N   T AA M L IH N S AH N
# 1/1 [==============================] - 0s 47ms/step
#   IH N S T IH T UW T IH D   IH N S T IH T UW T IH D
# 1/1 [==============================] - 0s 51ms/step
#   N OW N Z   N AW N Z
# 1/1 [==============================] - 0s 48ms/step
#   R OW L B AE K S   R AO L B AE K S
# 1/1 [==============================] - 0s 49ms/step
#   L UW S T R AY F   L UW S S T R AY F
# 1/1 [==============================] - 0s 46ms/step
#   JH AO D P ER   JH AA D F ER
# 1/1 [==============================] - 0s 46ms/step
#   IH N AE D IH K W AH S IY   IH N AE D AH K W IH S IY
# 1/1 [==============================] - 0s 46ms/step
#   S AE N T AO R AH M   S AE N T ER AH M
# 1/1 [==============================] - 0s 47ms/step
#   W ER K   W ER K
# 1/1 [==============================] - 0s 48ms/step
#   K AH L EH K T ER Z   K AH L EH K T ER Z
# 1/1 [==============================] - 0s 47ms/step
#   S AE N D S T OW N   S AE N D S T OW N
# 1/1 [==============================] - 0s 44ms/step
#   JH EH N R AH L   JH EH N ER AH L
# 1/1 [==============================] - 0s 46ms/step
#   N AA T IY   N AA T IY
# 1/1 [==============================] - 0s 48ms/step
#   AA B S T AH T R IH SH AH N   AA B S T EH T R IH SH AH N
# 1/1 [==============================] - 0s 48ms/step
#   M AA N AE SH   M AA N AH SH
# 1/1 [==============================] - 0s 47ms/step
#   R AO TH B ER D   R AO TH B ER D
# 1/1 [==============================] - 0s 46ms/step
#   W OW L F ER D   W OW L F ER D
# 1/1 [==============================] - 0s 46ms/step
#   L AA B IY   L AA B IY
# 1/1 [==============================] - 0s 46ms/step
#   N EH L AH N   N EH L AH N
# 1/1 [==============================] - 0s 46ms/step
#   D AA T IY   D AA T IY
# 1/1 [==============================] - 0s 49ms/step
#   EH K S T R EY N IY AH S L IY   EH K S T R EY N Y AH S L IY
# 1/1 [==============================] - 0s 53ms/step
#   K L AH M P   K L AH M P
# 1/1 [==============================] - 0s 48ms/step
#   B AA N S ER   B AA N S ER
# 1/1 [==============================] - 0s 46ms/step
#   EH N R UW T   EH N R AW T
# 1/1 [==============================] - 0s 47ms/step
#   M AH K N IH R   M AH K N IH R
# 1/1 [==============================] - 0s 57ms/step
#   M AH N F ER D Z   M AH N F ER D Z
# 1/1 [==============================] - 0s 53ms/step
#   P IY AH N IH S T   P IY AH N IH S T
# 1/1 [==============================] - 0s 49ms/step
#   AO R G AH N AY Z ER Z   AO R G AH N AY Z ER Z
# 1/1 [==============================] - 0s 47ms/step
#   AH D EY   AE D EY
# 1/1 [==============================] - 0s 44ms/step
#   P IH K AH L   P IH K AH L
# 1/1 [==============================] - 0s 45ms/step
#   AA R G Y UW AH B AH L   AA R G Y AH B AH L
# 1/1 [==============================] - 0s 48ms/step
#   IH R EH L AH V AH N S IY   IH R EH L AH V AH N S IY
# 1/1 [==============================] - 0s 47ms/step
#   IY S T ER N ER   IY S T ER N ER
# 1/1 [==============================] - 0s 48ms/step
#   G AH T M AA K ER   G AH T M AH CH ER
# 1/1 [==============================] - 0s 47ms/step
#   SH IY   SH IY
# 1/1 [==============================] - 0s 43ms/step
#   R AE T AH F AY IH NG   R AE T AH F AY IH NG
# 1/1 [==============================] - 0s 46ms/step
#   K IY S ER   K IY Z ER
# 1/1 [==============================] - 0s 47ms/step
#   HH AO Z   HH AO Z
# 1/1 [==============================] - 0s 47ms/step
#   EH R IH Z OW N AH Z   ER IH Z OW N AH Z
# 1/1 [==============================] - 0s 49ms/step
#   EH F AH K EY SH AH S   EH F AH K AH SH AH S
# 1/1 [==============================] - 0s 45ms/step
#   D AH D AH SH   D AH D AH SH
# 1/1 [==============================] - 0s 47ms/step
#   R IY M AH N   R IY M AH N
# 1/1 [==============================] - 0s 49ms/step
#   W AY S B ER G   W AY S B ER G
# 1/1 [==============================] - 0s 47ms/step
#   G R IY F   G R IY F
# 1/1 [==============================] - 0s 49ms/step
#   D AA M AH N   D AA M AH N
# 1/1 [==============================] - 0s 48ms/step
#   AY D AA R   EY D AA R
# 1/1 [==============================] - 0s 51ms/step
#   L AH P L AO N T   L AE P L AH N T
# 1/1 [==============================] - 0s 47ms/step
#   B EH S L ER   B EH S L ER
# 1/1 [==============================] - 0s 48ms/step
#   HH ER B IH S AH N   HH ER B IH S AH N
# 1/1 [==============================] - 0s 47ms/step
#   S IY Z IH Z   S IY Z IH Z
# 1/1 [==============================] - 0s 47ms/step
#   HH IH S T AH D R AH T   HH IH S T AE D R UW T
# 1/1 [==============================] - 0s 45ms/step
#   G R AE N D Z   G R AE N D Z
# 1/1 [==============================] - 0s 48ms/step
#   L IH B ER T EY   L IH B ER T
# 1/1 [==============================] - 0s 58ms/step
#   M IH L AH M IY T ER Z   M IH L AH M IY T ER Z
# 1/1 [==============================] - 0s 48ms/step
#   D AH L AO R IY Z   D EH L AO R IY Z
# 1/1 [==============================] - 0s 47ms/step
#   P L AE N T R AA N IH K   P L AE N T R AA N IH K
# 1/1 [==============================] - 0s 46ms/step
#   HH EH R   HH EH R
# 1/1 [==============================] - 0s 48ms/step
#   CH EH K IH T S   CH EH K IH T S
# 1/1 [==============================] - 0s 48ms/step
#   K AE L K IH N Z   K AE L K IH N Z
# 1/1 [==============================] - 0s 48ms/step
#   B AY IH NG   B Y UW IH NG
# 1/1 [==============================] - 0s 50ms/step
#   K IH R IY K OW   CH ER IY K OW
# 1/1 [==============================] - 0s 50ms/step
#   AH S AY K AH   OW S IY K AH
# 1/1 [==============================] - 0s 48ms/step
#   B AE N D AH JH D   B AE N D IH JH D
# 1/1 [==============================] - 0s 50ms/step
#   P R EH D AH L EH K SH AH N   P R EH D AH L EH K SH AH N
# 1/1 [==============================] - 0s 48ms/step
#   M AE N S L AO T ER   M AE N S L AA T ER
# 1/1 [==============================] - 0s 48ms/step
#   B L AA K B AH S T ER Z   B L AA K B AH S T ER Z
# 1/1 [==============================] - 0s 48ms/step
#   SH AW M B ER G   SH AW M B ER G
# 1/1 [==============================] - 0s 47ms/step
#   R EY V AH N   R EY V AH N
# 1/1 [==============================] - 0s 46ms/step
#   S P AW S IH Z   S P AW S IH Z
# 1/1 [==============================] - 0s 49ms/step
#   T EH S T R EY K   T EH S T R EY K
# 1/1 [==============================] - 0s 50ms/step
#   R EH G N ER   R EH G N ER
# 1/1 [==============================] - 0s 48ms/step
#   B ER T IY N OW   B ER T IY N OW
# 1/1 [==============================] - 0s 48ms/step
#   D EH T L AO F   D EH T L AO F
# 1/1 [==============================] - 0s 47ms/step
#   K R AO L   K R OW L
# 1/1 [==============================] - 0s 48ms/step
#   K W AA D R AH N T   K W AA D R AH N T
# 1/1 [==============================] - 0s 49ms/step
#   R OW M OW   R OW M OW
# 1/1 [==============================] - 0s 48ms/step
#   S AA N ER AH S   S AH N ER AH S
# 1/1 [==============================] - 0s 47ms/step
#   P R EH S T IY   P R EH S T IY
# 1/1 [==============================] - 0s 47ms/step
#   Y AH K UW Z AH   Y AA K UW S AH
# 1/1 [==============================] - 0s 47ms/step
#   M AE K R OW EH K AH N AA M IH K   M AE K R OW IY K AA N IH M IH K
# 1/1 [==============================] - 0s 47ms/step
#   M AH K IH Z M OW   M AH CH IH Z M OW
# 1/1 [==============================] - 0s 49ms/step
#   R OW Z AH B EH L   R OW Z AH B AH L
# 1/1 [==============================] - 0s 48ms/step
#   B R EY N IY   B R EY N IY
# 1/1 [==============================] - 0s 48ms/step
#   S IH N D OW N AH   S IH N D OW N AH
# 1/1 [==============================] - 0s 49ms/step
#   V OW T IH D   V OW T IH D
# 1/1 [==============================] - 0s 47ms/step
#   D EH N   D EH N
# 1/1 [==============================] - 0s 45ms/step
#   B IY B IY Z   B IY B IY Z
# 1/1 [==============================] - 0s 46ms/step
#   S UW P ER D OW M   S UW P ER D AA M
# 1/1 [==============================] - 0s 49ms/step
#   AE L T HH AO F   AE L TH AO F
# 1/1 [==============================] - 0s 49ms/step
#   M AW N T IH N IH R   M AW N T IH N IH R
# 1/1 [==============================] - 0s 47ms/step
#   EH Z M AH N   EH S M IH N
# 1/1 [==============================] - 0s 49ms/step
#   HH AE L AH N D EY L   HH AE L AH N D EY L
# 1/1 [==============================] - 0s 48ms/step
#   OW S EY JH AH Z   OW S IH JH IH Z
# 1/1 [==============================] - 0s 46ms/step
#   M EY OW   M AY OW
# 1/1 [==============================] - 0s 45ms/step
#   V OW L V OW   V OW L V OW
# 1/1 [==============================] - 0s 47ms/step
#   HH AE L AH M   HH AE L AH M
# 1/1 [==============================] - 0s 47ms/step
#   Z EH L M AH N   Z EH L M AH N
# 1/1 [==============================] - 0s 50ms/step
#   M AE D AH L EY N AH   M AA D AH L IY N AH
# 1/1 [==============================] - 0s 49ms/step
#   F Y UW JH AH T IH V   F Y UW JH IH T IH V
# 1/1 [==============================] - 0s 50ms/step
#   S L AE N IH D   S L AE N IH D
# 1/1 [==============================] - 0s 47ms/step
#   B L AH B ER   B L AH B ER
# 1/1 [==============================] - 0s 48ms/step
#   K AH L AW S K IY   K AH L AA S K IY
# 1/1 [==============================] - 0s 46ms/step
#   HH EH DH ER IH NG T AH N   HH EH DH ER IH NG T AH N
# 1/1 [==============================] - 0s 44ms/step
#   B EY ER Z   B EY ER Z
# 1/1 [==============================] - 0s 48ms/step
#   D IY HH Y UW M IH D AH F AY D   D IY HH Y UW M IH D AH F AY D
# 1/1 [==============================] - 0s 50ms/step
#   F L AO R SH AY M   F L AO R SH AY M
# 1/1 [==============================] - 0s 46ms/step
#   IH N K W AY ER Z   IH N K W AY ER Z
# 1/1 [==============================] - 0s 46ms/step
#   T W AY S   T W AY S
# 1/1 [==============================] - 0s 48ms/step
#   OW V ER R AY T S   OW V ER R AY T S
# 1/1 [==============================] - 0s 46ms/step
#   D IH NG G OW   D IY NG G OW
# 1/1 [==============================] - 0s 51ms/step
#   F R EY T L AY N ER   F R EY T L AY N ER
# 1/1 [==============================] - 0s 46ms/step
#   F L UW K S   F L UW K S
# 1/1 [==============================] - 0s 46ms/step
#   M AH K B R UW M   M AH K B R UW M
# 1/1 [==============================] - 0s 45ms/step
#   N UH R AH L   N UH R AH L
# 1/1 [==============================] - 0s 50ms/step
#   K AA M AH N ER Z   K AA M AH N ER Z
# 1/1 [==============================] - 0s 47ms/step
#   D AY AH B IY T IY Z   D AY AH B IY T S
# 1/1 [==============================] - 0s 47ms/step
#   N AH L AH F AY   N AH L AH F AY
# 1/1 [==============================] - 0s 48ms/step
#   R EY B IY   R EY B IY
# 1/1 [==============================] - 0s 49ms/step
#   G AA L IY N AH   G AA L IY N AH
# 1/1 [==============================] - 0s 46ms/step
#   B IH G IH N ER   B IH G IH N ER
# 1/1 [==============================] - 0s 48ms/step
#   K AA M AA R G OW   K AA M AA R G OW
# 1/1 [==============================] - 0s 45ms/step
#   Y AE S IH N   Y AA S IH N
# 1/1 [==============================] - 0s 47ms/step
#   Y EH R AH V AH N   Y ER V AH N
# 1/1 [==============================] - 0s 47ms/step
#   HH AA F EH Z   HH AE F EH Z
# 1/1 [==============================] - 0s 46ms/step
#   R IH NG ER Z   R IH NG ER Z
# 1/1 [==============================] - 0s 49ms/step
#   P R AA T AH S T AH N T   P R OW T EH S T AH N T
# 1/1 [==============================] - 0s 49ms/step
#   AE M B R IY AA N OW   AE M B R IY AA N OW
# 1/1 [==============================] - 0s 46ms/step
#   L IH M IH T EY SH AH N   L IH M AH T EY SH AH N
# 0.5845070422535211
